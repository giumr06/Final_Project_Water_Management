# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np
from amwag.app_utilities.preprocessing import *
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.holtwinters import Holt

from sklearn import set_config
set_config(transform_output="pandas")

RSEED = 5

# %%
df = pd.read_csv("../data/AQUASTAT_complete.csv", index_col=0)

# %% [markdown]
# pre-split preprocessing

# %%
pre_split_processor = get_pre_split_processor()

# %%
df_pre = pre_split_processor.transform(df)
df_pre.shape
# Out:
# (8575, 41)

# %% [markdown]
# limit years here!

# %%
df_pre = df_pre.query("year > 2000")

# %%
targets = ['gdp_per_capita', 'water_stress', 'total_population_with_access_to_safe_drinking_water']
df_targets = df_pre[["country", "year"] + targets]
df_targets.isna().sum()
# Out:
# country                                                 0
# year                                                    0
# gdp_per_capita                                          0
# water_stress                                           69
# total_population_with_access_to_safe_drinking_water     0
# dtype: int64

# %%
df_targets.groupby("country").apply(lambda group: group.fillna(method="bfill")).isna().sum() # only early years are missing in water_stress
# Out:
# country                                                0
# year                                                   0
# gdp_per_capita                                         0
# water_stress                                           0
# total_population_with_access_to_safe_drinking_water    0
# dtype: int64

# %%
# df_targets.to_csv("../data/targets_over_years.csv")

# %%
# df_pre.drop(columns=targets).to_csv("../data/features_over_years.csv")

# %%
df_ts = df_pre.sort_values("year").set_index("year")

# %%
#df_ts.index = pd.to_datetime(df_ts.index, format="%Y")

# %%
df_ts
# Out:
#                                                 country  \
# year
# 2001                                        Afghanistan
# 2001                                            Belgium
# 2001                                          Mauritius
# 2001                                         Mauritania
# 2001  United Kingdom of Great Britain and Northern I...
# ...                                                 ...
# 2020                                          Guatemala
# 2020                                             Greece
# 2020                                        Philippines
# 2020                                            Germany
# 2020                                           Zimbabwe
#
#       %_of_agricultural_gva_produced_by_irrigated_agriculture  \
# year
# 2001                                          44.702708
# 2001                                                NaN
# 2001                                                NaN
# 2001                                          24.845746
# 2001                                                NaN
# ...                                                 ...
# 2020                                          24.809144
# 2020                                          43.051419
# 2020                                          34.760355
# 2020                                           7.347628
# 2020                                           7.099892
#
#       %_of_agricultural_water_managed_area_equipped_for_irrigation  \
# year
# 2001                                         100.000000
# 2001                                         100.000000
# 2001                                         100.000000
# 2001                                          52.400577
# 2001                                         100.000000
# ...                                                 ...
# 2020                                         100.000000
# 2020                                         100.000000
# 2020                                          94.812910
# 2020                                         100.000000
# 2020                                          90.474331
#
#       %_of_total_country_area_cultivated  agricultural_water_withdrawal  \
# year
# 2001                           11.875440                      20.000000
# 2001                           28.358991                       0.037200
# 2001                           46.568627                       0.467840
# 2001                            0.448239                       1.430750
# 2001                           23.406264                       1.833000
# ...                                  ...                            ...
# 2020                           18.780421                       1.886000
# 2020                           24.402547                       8.107000
# 2020                           37.250000                      67.830825
# 2020                           33.203639                       0.399315
# 2020                           10.492374                       3.041070
#
#       agricultural_water_withdrawal_as_%_of_total_renewable_water_resources  \
# year
# 2001                                          30.613807
# 2001                                           0.203279
# 2001                                          17.006184
# 2001                                          12.550439
# 2001                                           1.246939
# ...                                                 ...
# 2020                                           1.474474
# 2020                                          11.852339
# 2020                                          14.160924
# 2020                                           0.259295
# 2020                                          15.205348
#
#       agricultural_water_withdrawal_as_%_of_total_water_withdrawal  \
# year
# 2001                                          98.518576
# 2001                                           0.521242
# 2001                                          72.160428
# 2001                                          93.078099
# 2001                                          12.079873
# ...                                                 ...
# 2020                                          56.737162
# 2020                                          80.092867
# 2020                                          78.995084
# 2020                                           1.401978
# 2020                                          80.635426
#
#       agriculture_value_added_%_gdp  \
# year
# 2001                      54.063068
# 2001                       1.109350
# 2001                       5.887679
# 2001                      24.868960
# 2001                       0.782121
# ...                             ...
# 2020                      10.243420
# 2020                       4.230805
# 2020                      10.184808
# 2020                       0.735310
# 2020                       8.272958
#
#       cultivated_area_arable_land_plus_permanent_crops  \
# year
# 2001                                         7753.0000
# 2001                                          865.8000
# 2001                                           95.0000
# 2001                                          462.0000
# 2001                                         5702.0000
# ...                                                ...
# 2020                                         2045.0000
# 2020                                         3220.1601
# 2020                                        11175.0000
# 2020                                        11862.0000
# 2020                                         4100.0000
#
#       dam_capacity_per_capita  ...  total_internal_renewable_water_resources  \
# year                           ...
# 2001                92.979179  ...                                    47.150
# 2001                13.983887  ...                                    12.000
# 2001                56.427708  ...                                     2.751
# 2001               185.020722  ...                                     0.400
# 2001                89.159636  ...                                   145.000
# ...                       ...  ...                                       ...
# 2020                25.890338  ...                                   109.200
# 2020              1182.187102  ...                                    58.000
# 2020                64.837836  ...                                   479.000
# 2020                47.741845  ...                                   107.000
# 2020              6723.437865  ...                                    12.260
#
#       total_internal_renewable_water_resources_per_capita  total_population  \
# year
# 2001                                        2182.164400           21606.988
# 2001                                        1162.901241           10319.019
# 2001                                        2304.180274            1193.917
# 2001                                         148.016578            2702.400
# 2001                                        2452.460823           59124.288
# ...                                                 ...                 ...
# 2020                                        6095.257488           17915.568
# 2020                                        5564.587884           10423.054
# 2020                                        4371.192625          109581.078
# 2020                                        1277.094363           83783.942
# 2020                                         824.871338           14862.924
#
#       total_population_with_access_to_safe_drinking_water  \
# year
# 2001                                               32.0
# 2001                                              100.0
# 2001                                               99.3
# 2001                                               43.3
# 2001                                              100.0
# ...                                                 ...
# 2020                                               92.8
# 2020                                              100.0
# 2020                                               91.8
# 2020                                              100.0
# 2020                                               76.9
#
#       total_renewable_groundwater  total_renewable_water_resources_per_capita  \
# year
# 2001                       10.650                                 3023.558860
# 2001                        0.900                                 1773.424392
# 2001                        0.893                                 2304.180274
# 2001                        0.300                                 4218.472469
# 2001                        9.800                                 2486.287869
# ...                           ...                                         ...
# 2020                       33.700                                 7139.600598
# 2020                       10.300                                 6562.376056
# 2020                      180.000                                 4371.192625
# 2020                       45.700                                 1838.061045
# 2020                        6.000                                 1345.630241
#
#       total_water_withdrawal  total_water_withdrawal_per_capita  \
# year
# 2001               20.300740                         939.545114
# 2001                7.136800                         691.616131
# 2001                0.648333                         543.030490
# 2001                1.537150                         568.809207
# 2001               15.174000                         256.645797
# ...                      ...                                ...
# 2020                3.324100                         185.542540
# 2020               10.122000                         971.116527
# 2020               85.867147                         783.594655
# 2020               28.482234                         339.948601
# 2020                3.771382                         253.744260
#
#       urban_population  water_resources_total_external_renewable
# year
# 2001          4648.139                                     18.18
# 2001         10028.603                                      6.30
# 2001           508.114                                      0.00
# 2001          1077.677                                     11.00
# 2001         46580.884                                      2.00
# ...                ...                                       ...
# 2020          9284.293                                     18.71
# 2020          8850.409                                     10.40
# 2020         52008.603                                      0.00
# 2020         63930.305                                     47.00
# 2020          5700.460                                      7.74
#
# [3238 rows x 40 columns]

# %%
df_imp = df_ts.groupby("country").apply(lambda group: group.interpolate())
df_imp = df_imp.apply(lambda group: group.fillna(method="ffill"))

# %%
df_imp.isna().sum().sum()
# Out:
# 0

# %%
df_imp = df_imp.drop("country", axis=1).reset_index().set_index("year")

# %%
for c in df_ts.country.unique():
    df_1 = df_ts.query("country == @c")
    if df_1.isna().sum().sum() > 10:
        print(c)
# Out:
# Mauritius
# United Kingdom of Great Britain and Northern Ireland
# Malta
# Luxembourg
# Lithuania
# Bhutan
# Latvia
# Lao People's Democratic Republic
# Kuwait
# Jordan
# Philippines
# Peru
# Azerbaijan
# Paraguay
# Panama
# Palestine
# Bahrain
# Oman
# North Macedonia
# Bangladesh
# Barbados
# United Arab Emirates
# Nepal
# Belarus
# Norway
# Puerto Rico
# Ethiopia
# Canada
# Egypt
# Central African Republic
# Yemen
# Chad
# Chile
# Croatia
# Costa Rica
# Comoros
# Democratic People's Republic of Korea
# Finland
# Israel
# Iraq
# Indonesia
# Iceland
# Honduras
# Guyana
# Burundi
# Germany
# Gambia
# Cambodia
# Qatar
# Switzerland
# Australia
# Turkmenistan
# Rwanda
# Thailand
# Sri Lanka
# Republic of Korea
# Slovenia
# Timor-Leste
# Saudi Arabia
# South Sudan

# %%
df_1 = df_ts.query("country == 'Chad'")
df_1.isna().sum().sum()
# Out:
# 40

# %%
df_int = df_1.drop("country", axis=1).interpolate(axis=1)
df_int.isna().sum().sum()
# Out:
# 0

# %%
df_int.head()
# Out:
#       %_of_agricultural_gva_produced_by_irrigated_agriculture  \
# year
# 2001                                           0.958824
# 2002                                           0.990247
# 2003                                           0.990247
# 2004                                           0.990247
# 2005                                           0.990247
#
#       %_of_agricultural_water_managed_area_equipped_for_irrigation  \
# year
# 2001                                          16.910839
# 2002                                          17.135515
# 2003                                          17.135515
# 2004                                          17.135515
# 2005                                          17.135515
#
#       %_of_total_country_area_cultivated  agricultural_water_withdrawal  \
# year
# 2001                            3.060748                       0.637253
# 2002                            2.904984                       0.672200
# 2003                            2.982866                       0.672200
# 2004                            2.982866                       0.672200
# 2005                            3.060748                       0.672200
#
#       agricultural_water_withdrawal_as_%_of_total_renewable_water_resources  \
# year
# 2001                                           1.394427
# 2002                                           1.470897
# 2003                                           1.470897
# 2004                                           1.470897
# 2005                                           1.470897
#
#       agricultural_water_withdrawal_as_%_of_total_water_withdrawal  \
# year
# 2001                                          77.682243
# 2002                                          78.039380
# 2003                                          77.492391
# 2004                                          76.953018
# 2005                                          76.421101
#
#       agriculture_value_added_%_gdp  \
# year
# 2001                      36.605330
# 2002                      34.445495
# 2003                      40.159436
# 2004                      28.339881
# 2005                      25.757433
#
#       cultivated_area_arable_land_plus_permanent_crops  \
# year
# 2001                                            3930.0
# 2002                                            3730.0
# 2003                                            3830.0
# 2004                                            3830.0
# 2005                                            3930.0
#
#       dam_capacity_per_capita  dependency_ratio  ...  \
# year                                             ...
# 2001              1998.588621         67.177243  ...
# 2002              1898.588621         67.177243  ...
# 2003              1948.588621         67.177243  ...
# 2004              1948.588621         67.177243  ...
# 2005              1998.588621         67.177243  ...
#
#       total_internal_renewable_water_resources  \
# year
# 2001                                      15.0
# 2002                                      15.0
# 2003                                      15.0
# 2004                                      15.0
# 2005                                      15.0
#
#       total_internal_renewable_water_resources_per_capita  total_population  \
# year
# 2001                                        1728.498715            8678.051
# 2002                                        1663.112595            9019.233
# 2003                                        1600.185024            9373.916
# 2004                                        1540.868929            9734.767
# 2005                                        1485.643778           10096.633
#
#       total_population_with_access_to_safe_drinking_water  \
# year
# 2001                                               45.2
# 2002                                               45.7
# 2003                                               46.2
# 2004                                               46.7
# 2005                                               47.2
#
#       total_renewable_groundwater  total_renewable_water_resources_per_capita  \
# year
# 2001                         11.5                                 5266.159418
# 2002                         11.5                                 5066.949706
# 2003                         11.5                                 4875.230373
# 2004                         11.5                                 4694.514003
# 2005                         11.5                                 4526.261378
#
#       total_water_withdrawal  total_water_withdrawal_per_capita  \
# year
# 2001                0.820333                          94.529674
# 2002                0.861360                          95.502578
# 2003                0.867440                          92.537633
# 2004                0.873520                          89.731988
# 2005                0.879600                          87.118151
#
#       urban_population  water_resources_total_external_renewable
# year
# 2001          1877.232                                      30.7
# 2002          1953.584                                      30.7
# 2003          2032.953                                      30.7
# 2004          2113.721                                      30.7
# 2005          2194.746                                      30.7
#
# [5 rows x 39 columns]

# %% [markdown]
# modeling

# %%
def fit_variable(train_var):
    holt_winters = Holt(train_var)
    return holt_winters.fit()

def predict_variable(model, pred_time):
    return model.forecast(pred_time[1] - pred_time[0] + 1)

def get_const_columns(df):
    unique_values = df.nunique()
    constant_columns = unique_values[unique_values == 1].index.tolist()
    return constant_columns

# %%
#creating the train and validation set
train = df_int.query("index < 2018")
valid = df_int.query("index >= 2018")

# %%
pd.to_datetime(train.index, format="%Y")
# Out:
# DatetimeIndex(['2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01',
#                '2017-01-01'],
#               dtype='datetime64[ns]', name='year', freq=None)

# %%
train.index = pd.to_datetime(train.index, format="%Y")
valid.index = pd.to_datetime(valid.index, format="%Y")

# const_cols = get_const_columns(train)
# train = train.drop(columns=const_cols)
# valid = valid.drop(columns=const_cols)

# %%
prediction_time_frame = (2018, 2020)
model_dict = {}
pred_df = pd.DataFrame({"year": np.arange(prediction_time_frame[0], prediction_time_frame[1]+1, 1)})
pred_df.set_index("year", inplace=True)
pred_df.index = pd.to_datetime(pred_df.index, format="%Y")

for var in train.columns.tolist():

    # fit model and get prediction
    var_model = fit_variable(train[var])
    var_pred = predict_variable(var_model, prediction_time_frame)

    # write results into dictionaries
    model_dict[var] = var_model
    pred_df[var] = var_pred.values

# %%
valid
# Out:
#             %_of_agricultural_gva_produced_by_irrigated_agriculture  \
# year
# 2018-01-01                                           0.990247
# 2019-01-01                                           0.990247
# 2020-01-01                                           0.990247
#
#             %_of_agricultural_water_managed_area_equipped_for_irrigation  \
# year
# 2018-01-01                                          17.135515
# 2019-01-01                                          17.135515
# 2020-01-01                                          17.135515
#
#             %_of_total_country_area_cultivated  agricultural_water_withdrawal  \
# year
# 2018-01-01                            4.079439                         0.6722
# 2019-01-01                            4.079439                         0.6722
# 2020-01-01                            4.079439                         0.6722
#
#             agricultural_water_withdrawal_as_%_of_total_renewable_water_resources  \
# year
# 2018-01-01                                           1.470897
# 2019-01-01                                           1.470897
# 2020-01-01                                           1.470897
#
#             agricultural_water_withdrawal_as_%_of_total_water_withdrawal  \
# year
# 2018-01-01                                          76.421101
# 2019-01-01                                          76.421101
# 2020-01-01                                          76.421101
#
#             agriculture_value_added_%_gdp  \
# year
# 2018-01-01                      32.442121
# 2019-01-01                      31.123508
# 2020-01-01                      31.436945
#
#             cultivated_area_arable_land_plus_permanent_crops  \
# year
# 2018-01-01                                            5238.0
# 2019-01-01                                            5238.0
# 2020-01-01                                            5238.0
#
#             dam_capacity_per_capita  dependency_ratio  ...  \
# year                                                   ...
# 2018-01-01              2652.588621         67.177243  ...
# 2019-01-01              2652.588621         67.177243  ...
# 2020-01-01              2652.588621         67.177243  ...
#
#             total_internal_renewable_water_resources  \
# year
# 2018-01-01                                      15.0
# 2019-01-01                                      15.0
# 2020-01-01                                      15.0
#
#             total_internal_renewable_water_resources_per_capita  \
# year
# 2018-01-01                                         969.134425
# 2019-01-01                                         940.623104
# 2020-01-01                                         913.193973
#
#             total_population  \
# year
# 2018-01-01         15477.729
# 2019-01-01         15946.876
# 2020-01-01         16425.864
#
#             total_population_with_access_to_safe_drinking_water  \
# year
# 2018-01-01                                               50.8
# 2019-01-01                                               50.8
# 2020-01-01                                               50.8
#
#             total_renewable_groundwater  \
# year
# 2018-01-01                         11.5
# 2019-01-01                         11.5
# 2020-01-01                         11.5
#
#             total_renewable_water_resources_per_capita  \
# year
# 2018-01-01                                 2952.629549
# 2019-01-01                                 2865.765056
# 2020-01-01                                 2782.197637
#
#             total_water_withdrawal  total_water_withdrawal_per_capita  \
# year
# 2018-01-01                  0.8796                          56.830043
# 2019-01-01                  0.8796                          55.158139
# 2020-01-01                  0.8796                          53.549695
#
#             urban_population  water_resources_total_external_renewable
# year
# 2018-01-01          3540.279                                      30.7
# 2019-01-01          3681.488                                      30.7
# 2020-01-01          3830.260                                      30.7
#
# [3 rows x 39 columns]

# %%
pred_df
# Out:
#             %_of_agricultural_gva_produced_by_irrigated_agriculture  \
# year
# 2018-01-01                                           0.990247
# 2019-01-01                                           0.990248
# 2020-01-01                                           0.990248
#
#             %_of_agricultural_water_managed_area_equipped_for_irrigation  \
# year
# 2018-01-01                                          17.135516
# 2019-01-01                                          17.135519
# 2020-01-01                                          17.135522
#
#             %_of_total_country_area_cultivated  agricultural_water_withdrawal  \
# year
# 2018-01-01                            4.071154                       0.672200
# 2019-01-01                            4.063350                       0.672200
# 2020-01-01                            4.055546                       0.672201
#
#             agricultural_water_withdrawal_as_%_of_total_renewable_water_resources  \
# year
# 2018-01-01                                           1.470897
# 2019-01-01                                           1.470898
# 2020-01-01                                           1.470900
#
#             agricultural_water_withdrawal_as_%_of_total_water_withdrawal  \
# year
# 2018-01-01                                          76.421101
# 2019-01-01                                          76.421100
# 2020-01-01                                          76.421100
#
#             agriculture_value_added_%_gdp  \
# year
# 2018-01-01                      35.664665
# 2019-01-01                      37.487027
# 2020-01-01                      39.309390
#
#             cultivated_area_arable_land_plus_permanent_crops  \
# year
# 2018-01-01                                       5227.362441
# 2019-01-01                                       5217.343052
# 2020-01-01                                       5207.323664
#
#             dam_capacity_per_capita  dependency_ratio  ...  \
# year                                                   ...
# 2018-01-01              2647.269803         67.177243  ...
# 2019-01-01              2642.260073         67.177243  ...
# 2020-01-01              2637.250344         67.177243  ...
#
#             total_internal_renewable_water_resources  \
# year
# 2018-01-01                                      15.0
# 2019-01-01                                      15.0
# 2020-01-01                                      15.0
#
#             total_internal_renewable_water_resources_per_capita  \
# year
# 2018-01-01                                         962.831527
# 2019-01-01                                         927.587100
# 2020-01-01                                         892.342672
#
#             total_population  \
# year
# 2018-01-01      15455.098223
# 2019-01-01      15893.774660
# 2020-01-01      16332.451096
#
#             total_population_with_access_to_safe_drinking_water  \
# year
# 2018-01-01                                          50.803744
# 2019-01-01                                          50.807487
# 2020-01-01                                          50.811231
#
#             total_renewable_groundwater  \
# year
# 2018-01-01                         11.5
# 2019-01-01                         11.5
# 2020-01-01                         11.5
#
#             total_renewable_water_resources_per_capita  \
# year
# 2018-01-01                                 2933.427000
# 2019-01-01                                 2826.049268
# 2020-01-01                                 2718.671536
#
#             total_water_withdrawal  total_water_withdrawal_per_capita  \
# year
# 2018-01-01                0.879598                          56.720689
# 2019-01-01                0.879596                          54.879925
# 2020-01-01                0.879594                          53.039161
#
#             urban_population  water_resources_total_external_renewable
# year
# 2018-01-01       3527.846596                                      30.7
# 2019-01-01       3650.403273                                      30.7
# 2020-01-01       3772.959949                                      30.7
#
# [3 rows x 39 columns]

# %%
cols = train.columns.tolist()
#check rmse
for e, i in enumerate(cols):
    # print(e, i)
    # display(pred[i])
    print('rmse value for', i, 'is : ', np.sqrt(mean_squared_error(pred_df[i], valid[i])))
# Out:
# rmse value for %_of_agricultural_gva_produced_by_irrigated_agriculture is :  4.7667737519787824e-07
# rmse value for %_of_agricultural_water_managed_area_equipped_for_irrigation is :  4.661740355124576e-06
# rmse value for %_of_total_country_area_cultivated is :  0.01730489544711331
# rmse value for agricultural_water_withdrawal is :  5.301269759614962e-07
# rmse value for agricultural_water_withdrawal_as_%_of_total_renewable_water_resources is :  1.5840683202339192e-06
# rmse value for agricultural_water_withdrawal_as_%_of_total_water_withdrawal is :  7.3622993600064e-09
# rmse value for agriculture_value_added_%_gdp is :  6.13336651676806
# rmse value for cultivated_area_arable_land_plus_permanent_crops is :  22.21789618839955
# rmse value for dam_capacity_per_capita is :  11.109027666605705
# rmse value for dependency_ratio is :  0.0
# rmse value for gdp_per_capita is :  137.40035987302812
# rmse value for groundwater_accounted_inflow is :  0.0
# rmse value for groundwater_entering_the_country_total is :  0.0
# rmse value for industrial_water_withdrawal is :  4.7254047021580703e-07
# rmse value for municipal_water_withdrawal is :  4.7254047021580703e-07
# rmse value for national_rainfall_index is :  0.0
# rmse value for population_density is :  0.05006315068384813
# rmse value for ratio_between_rainfed_and_irrigated_yields is :  0.0
# rmse value for rural_population is :  20.97132060608568
# rmse value for industrial_water_use_efficiency is :  0.26657481519987225
# rmse value for irrigated_agriculture_water_use_efficiency is :  0.012013015591794724
# rmse value for services_water_use_efficiency is :  9.21930588456515
# rmse value for water_use_efficiency is :  1.1497551739547949
# rmse value for water_stress is :  2.6362301908365318e-05
# rmse value for surface_water_entering_the_country_total is :  0.0
# rmse value for surface_water_leaving_the_country_to_other_countries_total is :  0.0
# rmse value for total_agricultural_water_managed_area is :  9.371690998794712e-05
# rmse value for total_area_of_the_country_excl_coastal_water is :  0.0
# rmse value for total_dam_capacity is :  0.0
# rmse value for total_internal_renewable_water_resources is :  0.0
# rmse value for total_internal_renewable_water_resources_per_capita is :  14.656519199189843
# rmse value for total_population is :  63.39788390053805
# rmse value for total_population_with_access_to_safe_drinking_water is :  0.008087054799544593
# rmse value for total_renewable_groundwater is :  0.0
# rmse value for total_renewable_water_resources_per_capita is :  44.652910494098805
# rmse value for total_water_withdrawal is :  4.312149746367867e-06
# rmse value for total_water_withdrawal_per_capita is :  0.3415675510620951
# rmse value for urban_population is :  38.31501318186067
# rmse value for water_resources_total_external_renewable is :  0.0

# %%
train.shape
# Out:
# (17, 39)

# %%
fig, axs = plt.subplots(10, 4, figsize=(20,20))
cols = valid.columns.tolist()

for i, ax in enumerate(axs.flat):
    if i<=train.shape[1]-1:
        ax.plot(train[cols[i]], label="train")
        ax.plot(valid[cols[i]], 'o', label="valid")
        ax.plot(pred_df[cols[i]], 'o', label="pred")
        ax.set_title(cols[i])
    if i==train.shape[1]-1:
        ax.legend(loc=(1.1, 0.1))
fig.tight_layout()

# %% [markdown]
# training for app

# %%
def fit_country(df):
    vars_dict = {}
    for var in df.columns.tolist():
        vars_dict[var] = fit_variable(df[var])
    return vars_dict

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# forecast_models_dict = {}

# for c in df_ts.country.unique():
#     df_c = df_ts.query("country == @c")
#     df_c = df_c.drop("country", axis=1).interpolate(axis=1)
#     df_c = df_c.fillna(method='bfill')
#     forecast_models_dict[c] = fit_country(df_c)

# %%
# with open("../ts_forecast_models.pkl", "wb") as file:
#     pkl.dump(forecast_models_dict, file)

# %%
import cProfile, pstats, io


def profile(fnc):
    
    """A decorator that uses cProfile to profile a function. 
       Starts the profile before executing a function, then exeuctes the function,
       then stops the profile, then prints out a diagnostics report.
       
       Lots of boilerplate code from the Python 3 documentation:
       https://docs.python.org/3/library/profile.html#profile.Profile
       """
    
    def inner(*args, **kwargs):
        
        pr = cProfile.Profile()
        pr.enable() ### start the profiler
        
        retval = fnc(*args, **kwargs) ### then actually execute the function
        
        pr.disable() ### then we stop the profiler
        
        ###then print the results to the standard output
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        
        ### then return the actual return value of the inner function we executed
        return retval

    ### execute the innter function
    return inner

# %%
used_columns = ['country', 'year',
       '%_of_agricultural_gva_produced_by_irrigated_agriculture',
       '%_of_agricultural_water_managed_area_equipped_for_irrigation',
       '%_of_total_country_area_cultivated', 'agricultural_water_withdrawal',
       'agricultural_water_withdrawal_as_%_of_total_renewable_water_resources',
       'agricultural_water_withdrawal_as_%_of_total_water_withdrawal',
       'agriculture_value_added_%_gdp',
       'cultivated_area_arable_land_plus_permanent_crops',
       'dam_capacity_per_capita', 'dependency_ratio', 'gdp_per_capita',
       'groundwater_accounted_inflow',
       'groundwater_entering_the_country_total', 'industrial_water_withdrawal',
       'municipal_water_withdrawal', 'national_rainfall_index',
       'population_density', 'ratio_between_rainfed_and_irrigated_yields',
       'rural_population', 'industrial_water_use_efficiency',
       'irrigated_agriculture_water_use_efficiency',
       'services_water_use_efficiency', 'water_use_efficiency', 'water_stress',
       'surface_water_entering_the_country_total',
       'surface_water_leaving_the_country_to_other_countries_total',
       'total_agricultural_water_managed_area',
       'total_area_of_the_country_excl_coastal_water', 'total_dam_capacity',
       'total_internal_renewable_water_resources',
       'total_internal_renewable_water_resources_per_capita',
       'total_population',
       'total_population_with_access_to_safe_drinking_water',
       'total_renewable_groundwater',
       'total_renewable_water_resources_per_capita', 'total_water_withdrawal',
       'total_water_withdrawal_per_capita', 'urban_population',
       'water_resources_total_external_renewable']

# %%
@profile
def forecast_dataset(model_dict, used_columns, n_years):
    df = pd.DataFrame(columns=used_columns)
    for i, (c, vm_dict) in enumerate(model_dict.items()):
        #print(c, vm_dict)
        c_forecasts = {v: m.forecast(n_years) for v, m in vm_dict.items()}

        df_c = pd.DataFrame(c_forecasts)

        df_c.insert(0, "year", [2020 + n+1 for n in range(n_years)])
        df_c.insert(0, "country", [c]*n_years)
        df = pd.concat([df, df_c])

        #display(df_c)
        #if i == 3:  break

    #df.reset_index(inplace=True)
    return df

# %%
# fc = forecast_dataset(forecast_models_dict, used_columns, 5)

# %%
# fc.isna().sum()

# %%
# fc[["country","%_of_agricultural_gva_produced_by_irrigated_agriculture", "%_of_agricultural_water_managed_area_equipped_for_irrigation"]].loc[fc["%_of_agricultural_gva_produced_by_irrigated_agriculture"].isnull()]["country"].unique()

# %%
# df_ts.query("country == 'Belgium'")["%_of_agricultural_gva_produced_by_irrigated_agriculture"].to_frame().fillna(method='bfill')

# %%
# fc

# %%
# fc_targets = fc[["country", "year"] + targets]
# fc_targets.head(5)

# %%
#fc = fc.drop(columns=targets)

# %%
# with open("forecast_2021_2025.pkl", "wb") as file:
#     pkl.dump(fc, file)
# with open("forecast_2021_2025_targets.pkl", "wb") as file:
#     pkl.dump(fc_targets, file)

# fc.to_csv("../data/forecast_2021_2025.csv")
# fc_targets.to_csv("forecast_2021_2025_targets.csv")

# %% [markdown]
# test goodness

# %%
forecast_models_dict = {}
valid_dfs_dict = {}

for c in df_ts.country.unique():
    df_c = df_ts.query("country == @c")
    df_c = df_c.drop("country", axis=1).interpolate(axis=1)
    df_c = df_c.fillna(method='bfill')
    #creating the train and validation set
    train = df_c.query("index < 2017")
    valid = df_c.query("index >= 2017")

    train.index = pd.to_datetime(train.index, format="%Y")
    valid.index = pd.to_datetime(valid.index, format="%Y")

    forecast_models_dict[c] = fit_country(train)
    valid_dfs_dict[c] = valid

# %%
def forecast_dataset(model_dict, used_columns, n_years):
    df = pd.DataFrame(columns=used_columns)
    for i, (c, vm_dict) in enumerate(model_dict.items()):
        #print(c, vm_dict)
        c_forecasts = {v: m.forecast(n_years) for v, m in vm_dict.items()}

        df_c = pd.DataFrame(c_forecasts)

        df_c.insert(0, "year", [2016 + n+1 for n in range(n_years)])
        df_c.insert(0, "country", [c]*n_years)
        df = pd.concat([df, df_c])

    return df

# %%
fc = forecast_dataset(forecast_models_dict, used_columns, 4)

# %%
with open("country_forecast_dfs.pkl", "rb") as file:
    fc_multi = pkl.load(file)
#df_valid_multi = pd.read_csv("VAR_valid.csv")
with open("country_valid_dfs.pkl", "rb") as file:
    valid_multi = pkl.load(file)

# %%
fc_multi = {df.country.iloc[0]: df.drop("country", axis=1).set_index("year") for df in fc_multi}
# fc_multi

# %%
fig = plt.figure()
var_list = [var for var in fc.columns.tolist() if not var in ["year", "country"]]

for i, c in enumerate(fc.country.unique()):
    print(i, c)
    for j, var in enumerate(var_list):
        if i==0 and j==0:
            plt.plot(fc.query("country == @c")[var], valid_dfs_dict[c][var], "o", alpha=0.2, color="C0", label="univariate")
            plt.plot(fc_multi[c][var], valid_multi[c][var], "o", alpha=0.2, color="C1", label="multivariate")
        else:
            plt.plot(fc.query("country == @c")[var], valid_dfs_dict[c][var], "o", alpha=0.2, color="C0")
            plt.plot(fc_multi[c][var], valid_multi[c][var], "o", alpha=0.2, color="C1")
plt.plot([-10, 2e6], [-10, 2e6], color="red", alpha=0.8)
plt.xscale('log')
plt.yscale('log')
plt.title("Forecast performance comparison")
plt.xlabel("forecasted value")
plt.ylabel("actual value")
plt.legend()
# Out:
# 0 Afghanistan
# 1 Belgium
# 2 Mauritius
# 3 Mauritania
# 4 United Kingdom of Great Britain and Northern Ireland
# 5 Malta
# 6 Mali
# 7 Belize
# 8 Malaysia
# 9 Malawi
# 10 Madagascar
# 11 Luxembourg
# 12 Benin
# 13 Lithuania
# 14 Mexico
# 15 Libya
# 16 Lesotho
# 17 United Republic of Tanzania
# 18 Bhutan
# 19 Lebanon
# 20 Latvia
# 21 Lao People's Democratic Republic
# 22 Bolivia (Plurinational State of)
# 23 Kyrgyzstan
# 24 Kuwait
# 25 Kenya
# 26 Kazakhstan
# 27 Botswana
# 28 Jordan
# 29 Liberia
# 30 Japan
# 31 Mongolia
# 32 Mozambique
# 33 Austria
# 34 Portugal
# 35 Poland
# 36 Philippines
# 37 Peru
# 38 Azerbaijan
# 39 Paraguay
# 40 Panama
# 41 Ukraine
# 42 Palestine
# 43 Zimbabwe
# 44 Bahrain
# 45 Pakistan
# 46 Morocco
# 47 Oman
# 48 North Macedonia
# 49 Bangladesh
# 50 Nigeria
# 51 Niger
# 52 Nicaragua
# 53 New Zealand
# 54 Netherlands (Kingdom of the)
# 55 Barbados
# 56 United Arab Emirates
# 57 Nepal
# 58 Namibia
# 59 Myanmar
# 60 Belarus
# 61 Norway
# 62 Puerto Rico
# 63 United States of America
# 64 Zambia
# 65 Cameroon
# 66 Ethiopia
# 67 Eswatini
# 68 Estonia
# 69 Eritrea
# 70 Venezuela (Bolivarian Republic of)
# 71 Canada
# 72 El Salvador
# 73 Egypt
# 74 Ecuador
# 75 Central African Republic
# 76 Dominican Republic
# 77 Denmark
# 78 Fiji
# 79 Democratic Republic of the Congo
# 80 Yemen
# 81 Chad
# 82 Côte d'Ivoire
# 83 Czechia
# 84 Viet Nam
# 85 Cyprus
# 86 Chile
# 87 Cuba
# 88 Croatia
# 89 Costa Rica
# 90 Congo
# 91 China
# 92 Comoros
# 93 Democratic People's Republic of Korea
# 94 Jamaica
# 95 Finland
# 96 Gabon
# 97 Brazil
# 98 Italy
# 99 Israel
# 100 Ireland
# 101 Iraq
# 102 Bulgaria
# 103 Iran (Islamic Republic of)
# 104 Indonesia
# 105 India
# 106 Iceland
# 107 Hungary
# 108 Burkina Faso
# 109 Uruguay
# 110 France
# 111 Honduras
# 112 Guyana
# 113 Burundi
# 114 Guinea-Bissau
# 115 Guinea
# 116 Guatemala
# 117 Greece
# 118 Cabo Verde
# 119 Ghana
# 120 Germany
# 121 Uzbekistan
# 122 Georgia
# 123 Gambia
# 124 Cambodia
# 125 Haiti
# 126 Qatar
# 127 Colombia
# 128 Switzerland
# 129 Romania
# 130 South Africa
# 131 Sweden
# 132 Uganda
# 133 Australia
# 134 Syrian Arab Republic
# 135 Tunisia
# 136 Slovakia
# 137 Armenia
# 138 Somalia
# 139 Turkmenistan
# 140 Albania
# 141 Sierra Leone
# 142 Spain
# 143 Suriname
# 144 Rwanda
# 145 Thailand
# 146 Trinidad and Tobago
# 147 Sri Lanka
# 148 Senegal
# 149 Republic of Korea
# 150 Slovenia
# 151 Algeria
# 152 Russian Federation
# 153 Togo
# 154 Timor-Leste
# 155 Saudi Arabia
# 156 Angola
# 157 Republic of Moldova
# 158 Tajikistan
# 159 Argentina
# 160 Türkiye
# 161 South Sudan
# 162 Sudan

# %%
fig, axs = plt.subplots(1,2, figsize=(8,4), sharey=True)
var_list = [var for var in fc.columns.tolist() if not var in ["year", "country"]]

for i, c in enumerate(fc.country.unique()):
    print(i, c)
    for j, var in enumerate(var_list):
        if i==0 and j==0:
            axs[0].plot(fc.query("country == @c")[var], valid_dfs_dict[c][var], "o", alpha=0.2, color="C0", label="univariate")
            axs[1].plot(fc_multi[c][var], valid_multi[c][var], "o", alpha=0.2, color="C1", label="multivariate")
        else:
            axs[0].plot(fc.query("country == @c")[var], valid_dfs_dict[c][var], "o", alpha=0.2, color="C0")
            axs[1].plot(fc_multi[c][var], valid_multi[c][var], "o", alpha=0.2, color="C1")
axs[0].plot([-10, 2e6], [-10, 2e6], color="red", alpha=0.8)
axs[1].plot([-10, 2e6], [-10, 2e6], color="red", alpha=0.8)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[0].set_title("Holt Winters'")
axs[1].set_title("VAR")
axs[0].set_xlabel("forecasted value")
axs[1].set_xlabel("forecasted value")
axs[0].set_ylabel("actual value")
axs[0].legend(loc="lower right")
axs[1].legend(loc="lower right")
# Out:
# 0 Afghanistan
# 1 Belgium
# 2 Mauritius
# 3 Mauritania
# 4 United Kingdom of Great Britain and Northern Ireland
# 5 Malta
# 6 Mali
# 7 Belize
# 8 Malaysia
# 9 Malawi
# 10 Madagascar
# 11 Luxembourg
# 12 Benin
# 13 Lithuania
# 14 Mexico
# 15 Libya
# 16 Lesotho
# 17 United Republic of Tanzania
# 18 Bhutan
# 19 Lebanon
# 20 Latvia
# 21 Lao People's Democratic Republic
# 22 Bolivia (Plurinational State of)
# 23 Kyrgyzstan
# 24 Kuwait
# 25 Kenya
# 26 Kazakhstan
# 27 Botswana
# 28 Jordan
# 29 Liberia
# 30 Japan
# 31 Mongolia
# 32 Mozambique
# 33 Austria
# 34 Portugal
# 35 Poland
# 36 Philippines
# 37 Peru
# 38 Azerbaijan
# 39 Paraguay
# 40 Panama
# 41 Ukraine
# 42 Palestine
# 43 Zimbabwe
# 44 Bahrain
# 45 Pakistan
# 46 Morocco
# 47 Oman
# 48 North Macedonia
# 49 Bangladesh
# 50 Nigeria
# 51 Niger
# 52 Nicaragua
# 53 New Zealand
# 54 Netherlands (Kingdom of the)
# 55 Barbados
# 56 United Arab Emirates
# 57 Nepal
# 58 Namibia
# 59 Myanmar
# 60 Belarus
# 61 Norway
# 62 Puerto Rico
# 63 United States of America
# 64 Zambia
# 65 Cameroon
# 66 Ethiopia
# 67 Eswatini
# 68 Estonia
# 69 Eritrea
# 70 Venezuela (Bolivarian Republic of)
# 71 Canada
# 72 El Salvador
# 73 Egypt
# 74 Ecuador
# 75 Central African Republic
# 76 Dominican Republic
# 77 Denmark
# 78 Fiji
# 79 Democratic Republic of the Congo
# 80 Yemen
# 81 Chad
# 82 Côte d'Ivoire
# 83 Czechia
# 84 Viet Nam
# 85 Cyprus
# 86 Chile
# 87 Cuba
# 88 Croatia
# 89 Costa Rica
# 90 Congo
# 91 China
# 92 Comoros
# 93 Democratic People's Republic of Korea
# 94 Jamaica
# 95 Finland
# 96 Gabon
# 97 Brazil
# 98 Italy
# 99 Israel
# 100 Ireland
# 101 Iraq
# 102 Bulgaria
# 103 Iran (Islamic Republic of)
# 104 Indonesia
# 105 India
# 106 Iceland
# 107 Hungary
# 108 Burkina Faso
# 109 Uruguay
# 110 France
# 111 Honduras
# 112 Guyana
# 113 Burundi
# 114 Guinea-Bissau
# 115 Guinea
# 116 Guatemala
# 117 Greece
# 118 Cabo Verde
# 119 Ghana
# 120 Germany
# 121 Uzbekistan
# 122 Georgia
# 123 Gambia
# 124 Cambodia
# 125 Haiti
# 126 Qatar
# 127 Colombia
# 128 Switzerland
# 129 Romania
# 130 South Africa
# 131 Sweden
# 132 Uganda
# 133 Australia
# 134 Syrian Arab Republic
# 135 Tunisia
# 136 Slovakia
# 137 Armenia
# 138 Somalia
# 139 Turkmenistan
# 140 Albania
# 141 Sierra Leone
# 142 Spain
# 143 Suriname
# 144 Rwanda
# 145 Thailand
# 146 Trinidad and Tobago
# 147 Sri Lanka
# 148 Senegal
# 149 Republic of Korea
# 150 Slovenia
# 151 Algeria
# 152 Russian Federation
# 153 Togo
# 154 Timor-Leste
# 155 Saudi Arabia
# 156 Angola
# 157 Republic of Moldova
# 158 Tajikistan
# 159 Argentina
# 160 Türkiye
# 161 South Sudan
# 162 Sudan

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mape_dict_uni = {var: [] for var in var_list} 
mape_dict_uni["country"] = []
for i, c in enumerate(fc.country.unique()):
    print(i, c)
    mape_dict_uni["country"].append(c)
    for j, var in enumerate(var_list):
        y_true = valid_dfs_dict[c][var]
        y_pred = fc.query("country == @c")[var]
        mape_dict_uni[var].append(mean_absolute_percentage_error(y_true, y_pred))
# Out:
# 0 Afghanistan
# 1 Belgium
# 2 Mauritius
# 3 Mauritania
# 4 United Kingdom of Great Britain and Northern Ireland
# 5 Malta
# 6 Mali
# 7 Belize
# 8 Malaysia
# 9 Malawi
# 10 Madagascar
# 11 Luxembourg
# 12 Benin
# 13 Lithuania
# 14 Mexico
# 15 Libya
# 16 Lesotho
# 17 United Republic of Tanzania
# 18 Bhutan
# 19 Lebanon
# 20 Latvia
# 21 Lao People's Democratic Republic
# 22 Bolivia (Plurinational State of)
# 23 Kyrgyzstan
# 24 Kuwait
# 25 Kenya
# 26 Kazakhstan
# 27 Botswana
# 28 Jordan
# 29 Liberia
# 30 Japan
# 31 Mongolia
# 32 Mozambique
# 33 Austria
# 34 Portugal
# 35 Poland
# 36 Philippines
# 37 Peru
# 38 Azerbaijan
# 39 Paraguay
# 40 Panama
# 41 Ukraine
# 42 Palestine
# 43 Zimbabwe
# 44 Bahrain
# 45 Pakistan
# 46 Morocco
# 47 Oman
# 48 North Macedonia
# 49 Bangladesh
# 50 Nigeria
# 51 Niger
# 52 Nicaragua
# 53 New Zealand
# 54 Netherlands (Kingdom of the)
# 55 Barbados
# 56 United Arab Emirates
# 57 Nepal
# 58 Namibia
# 59 Myanmar
# 60 Belarus
# 61 Norway
# 62 Puerto Rico
# 63 United States of America
# 64 Zambia
# 65 Cameroon
# 66 Ethiopia
# 67 Eswatini
# 68 Estonia
# 69 Eritrea
# 70 Venezuela (Bolivarian Republic of)
# 71 Canada
# 72 El Salvador
# 73 Egypt
# 74 Ecuador
# 75 Central African Republic
# 76 Dominican Republic
# 77 Denmark
# 78 Fiji
# 79 Democratic Republic of the Congo
# 80 Yemen
# 81 Chad
# 82 Côte d'Ivoire
# 83 Czechia
# 84 Viet Nam
# 85 Cyprus
# 86 Chile
# 87 Cuba
# 88 Croatia
# 89 Costa Rica
# 90 Congo
# 91 China
# 92 Comoros
# 93 Democratic People's Republic of Korea
# 94 Jamaica
# 95 Finland
# 96 Gabon
# 97 Brazil
# 98 Italy
# 99 Israel
# 100 Ireland
# 101 Iraq
# 102 Bulgaria
# 103 Iran (Islamic Republic of)
# 104 Indonesia
# 105 India
# 106 Iceland
# 107 Hungary
# 108 Burkina Faso
# 109 Uruguay
# 110 France
# 111 Honduras
# 112 Guyana
# 113 Burundi
# 114 Guinea-Bissau
# 115 Guinea
# 116 Guatemala
# 117 Greece
# 118 Cabo Verde
# 119 Ghana
# 120 Germany
# 121 Uzbekistan
# 122 Georgia
# 123 Gambia
# 124 Cambodia
# 125 Haiti
# 126 Qatar
# 127 Colombia
# 128 Switzerland
# 129 Romania
# 130 South Africa
# 131 Sweden
# 132 Uganda
# 133 Australia
# 134 Syrian Arab Republic
# 135 Tunisia
# 136 Slovakia
# 137 Armenia
# 138 Somalia
# 139 Turkmenistan
# 140 Albania
# 141 Sierra Leone
# 142 Spain
# 143 Suriname
# 144 Rwanda
# 145 Thailand
# 146 Trinidad and Tobago
# 147 Sri Lanka
# 148 Senegal
# 149 Republic of Korea
# 150 Slovenia
# 151 Algeria
# 152 Russian Federation
# 153 Togo
# 154 Timor-Leste
# 155 Saudi Arabia
# 156 Angola
# 157 Republic of Moldova
# 158 Tajikistan
# 159 Argentina
# 160 Türkiye
# 161 South Sudan
# 162 Sudan

# %%
mape_dict_multi = {var: [] for var in var_list} 
mape_dict_multi["country"] = []
for i, c in enumerate(fc.country.unique()):
    print(i, c)
    mape_dict_multi["country"].append(c)
    for j, var in enumerate(var_list):
        y_true = valid_multi[c][var]
        y_pred = fc_multi[c][var]
        mape_dict_multi[var].append(mean_absolute_percentage_error(y_true, y_pred))
# Out:
# 0 Afghanistan
# 1 Belgium
# 2 Mauritius
# 3 Mauritania
# 4 United Kingdom of Great Britain and Northern Ireland
# 5 Malta
# 6 Mali
# 7 Belize
# 8 Malaysia
# 9 Malawi
# 10 Madagascar
# 11 Luxembourg
# 12 Benin
# 13 Lithuania
# 14 Mexico
# 15 Libya
# 16 Lesotho
# 17 United Republic of Tanzania
# 18 Bhutan
# 19 Lebanon
# 20 Latvia
# 21 Lao People's Democratic Republic
# 22 Bolivia (Plurinational State of)
# 23 Kyrgyzstan
# 24 Kuwait
# 25 Kenya
# 26 Kazakhstan
# 27 Botswana
# 28 Jordan
# 29 Liberia
# 30 Japan
# 31 Mongolia
# 32 Mozambique
# 33 Austria
# 34 Portugal
# 35 Poland
# 36 Philippines
# 37 Peru
# 38 Azerbaijan
# 39 Paraguay
# 40 Panama
# 41 Ukraine
# 42 Palestine
# 43 Zimbabwe
# 44 Bahrain
# 45 Pakistan
# 46 Morocco
# 47 Oman
# 48 North Macedonia
# 49 Bangladesh
# 50 Nigeria
# 51 Niger
# 52 Nicaragua
# 53 New Zealand
# 54 Netherlands (Kingdom of the)
# 55 Barbados
# 56 United Arab Emirates
# 57 Nepal
# 58 Namibia
# 59 Myanmar
# 60 Belarus
# 61 Norway
# 62 Puerto Rico
# 63 United States of America
# 64 Zambia
# 65 Cameroon
# 66 Ethiopia
# 67 Eswatini
# 68 Estonia
# 69 Eritrea
# 70 Venezuela (Bolivarian Republic of)
# 71 Canada
# 72 El Salvador
# 73 Egypt
# 74 Ecuador
# 75 Central African Republic
# 76 Dominican Republic
# 77 Denmark
# 78 Fiji
# 79 Democratic Republic of the Congo
# 80 Yemen
# 81 Chad
# 82 Côte d'Ivoire
# 83 Czechia
# 84 Viet Nam
# 85 Cyprus
# 86 Chile
# 87 Cuba
# 88 Croatia
# 89 Costa Rica
# 90 Congo
# 91 China
# 92 Comoros
# 93 Democratic People's Republic of Korea
# 94 Jamaica
# 95 Finland
# 96 Gabon
# 97 Brazil
# 98 Italy
# 99 Israel
# 100 Ireland
# 101 Iraq
# 102 Bulgaria
# 103 Iran (Islamic Republic of)
# 104 Indonesia
# 105 India
# 106 Iceland
# 107 Hungary
# 108 Burkina Faso
# 109 Uruguay
# 110 France
# 111 Honduras
# 112 Guyana
# 113 Burundi
# 114 Guinea-Bissau
# 115 Guinea
# 116 Guatemala
# 117 Greece
# 118 Cabo Verde
# 119 Ghana
# 120 Germany
# 121 Uzbekistan
# 122 Georgia
# 123 Gambia
# 124 Cambodia
# 125 Haiti
# 126 Qatar
# 127 Colombia
# 128 Switzerland
# 129 Romania
# 130 South Africa
# 131 Sweden
# 132 Uganda
# 133 Australia
# 134 Syrian Arab Republic
# 135 Tunisia
# 136 Slovakia
# 137 Armenia
# 138 Somalia
# 139 Turkmenistan
# 140 Albania
# 141 Sierra Leone
# 142 Spain
# 143 Suriname
# 144 Rwanda
# 145 Thailand
# 146 Trinidad and Tobago
# 147 Sri Lanka
# 148 Senegal
# 149 Republic of Korea
# 150 Slovenia
# 151 Algeria
# 152 Russian Federation
# 153 Togo
# 154 Timor-Leste
# 155 Saudi Arabia
# 156 Angola
# 157 Republic of Moldova
# 158 Tajikistan
# 159 Argentina
# 160 Türkiye
# 161 South Sudan
# 162 Sudan

# %%
y_true
# Out:
# year
# 2017    33.8
# 2018    33.8
# 2019    33.8
# 2020    33.8
# Name: water_resources_total_external_renewable, dtype: float64

# %%
df_mape_uni = pd.DataFrame(mape_dict_uni).set_index("country")
df_mape_multi = pd.DataFrame(mape_dict_multi).set_index("country")
df_mape_uni
# Out:
#                                                     %_of_agricultural_gva_produced_by_irrigated_agriculture  \
# country
# Afghanistan                                                                                  0.000960
# Belgium                                                                                      0.346369
# Mauritius                                                                                    0.029877
# Mauritania                                                                                   0.000019
# United Kingdom of Great Britain and Northern Ir...                                           0.593149
# ...                                                                                               ...
# Tajikistan                                                                                   0.005669
# Argentina                                                                                    0.036326
# Türkiye                                                                                      0.000000
# South Sudan                                                                                  0.000000
# Sudan                                                                                        0.000000
#
#                                                     %_of_agricultural_water_managed_area_equipped_for_irrigation  \
# country
# Afghanistan                                                                                  0.000000
# Belgium                                                                                      0.000000
# Mauritius                                                                                    0.000000
# Mauritania                                                                                   0.005089
# United Kingdom of Great Britain and Northern Ir...                                           0.000000
# ...                                                                                               ...
# Tajikistan                                                                                   0.000000
# Argentina                                                                                    0.000000
# Türkiye                                                                                      0.000000
# South Sudan                                                                                  0.000000
# Sudan                                                                                        0.000000
#
#                                                     %_of_total_country_area_cultivated  \
# country
# Afghanistan                                                                   0.011911
# Belgium                                                                       0.045607
# Mauritius                                                                     0.015183
# Mauritania                                                                    0.004623
# United Kingdom of Great Britain and Northern Ir...                            0.007237
# ...                                                                                ...
# Tajikistan                                                                    0.039740
# Argentina                                                                     0.016504
# Türkiye                                                                       0.010980
# South Sudan                                                                   0.011949
# Sudan                                                                         0.010782
#
#                                                     agricultural_water_withdrawal  \
# country
# Afghanistan                                                              0.000000
# Belgium                                                                  0.085807
# Mauritius                                                                0.059705
# Mauritania                                                               0.000032
# United Kingdom of Great Britain and Northern Ir...                       0.135309
# ...                                                                           ...
# Tajikistan                                                               0.290888
# Argentina                                                                0.000427
# Türkiye                                                                  0.096171
# South Sudan                                                              0.000000
# Sudan                                                                    0.000000
#
#                                                     agricultural_water_withdrawal_as_%_of_total_renewable_water_resources  \
# country
# Afghanistan                                                                                  0.000000
# Belgium                                                                                      0.085807
# Mauritius                                                                                    0.059786
# Mauritania                                                                                   0.000033
# United Kingdom of Great Britain and Northern Ir...                                           0.135332
# ...                                                                                               ...
# Tajikistan                                                                                   0.290908
# Argentina                                                                                    0.000419
# Türkiye                                                                                      0.096169
# South Sudan                                                                                  0.000000
# Sudan                                                                                        0.000000
#
#                                                     agricultural_water_withdrawal_as_%_of_total_water_withdrawal  \
# country
# Afghanistan                                                                              3.478434e-07
# Belgium                                                                                  5.034078e-02
# Mauritius                                                                                4.306116e-02
# Mauritania                                                                               3.114162e-07
# United Kingdom of Great Britain and Northern Ir...                                       7.324812e-02
# ...                                                                                               ...
# Tajikistan                                                                               1.658923e-01
# Argentina                                                                                7.487889e-05
# Türkiye                                                                                  1.552211e-02
# South Sudan                                                                              0.000000e+00
# Sudan                                                                                    0.000000e+00
#
#                                                     agriculture_value_added_%_gdp  \
# country
# Afghanistan                                                              0.102902
# Belgium                                                                  0.056869
# Mauritius                                                                0.066741
# Mauritania                                                               0.082284
# United Kingdom of Great Britain and Northern Ir...                       0.183952
# ...                                                                           ...
# Tajikistan                                                               0.052277
# Argentina                                                                0.097905
# Türkiye                                                                  0.158856
# South Sudan                                                              0.301601
# Sudan                                                                    0.296207
#
#                                                     cultivated_area_arable_land_plus_permanent_crops  \
# country
# Afghanistan                                                                                 0.011925
# Belgium                                                                                     0.045607
# Mauritius                                                                                   0.015181
# Mauritania                                                                                  0.004057
# United Kingdom of Great Britain and Northern Ir...                                          0.007237
# ...                                                                                              ...
# Tajikistan                                                                                  0.039402
# Argentina                                                                                   0.017083
# Türkiye                                                                                     0.011103
# South Sudan                                                                                 0.007121
# Sudan                                                                                       0.010782
#
#                                                     dam_capacity_per_capita  \
# country
# Afghanistan                                                        0.026876
# Belgium                                                            0.001680
# Mauritius                                                          0.001890
# Mauritania                                                         0.019411
# United Kingdom of Great Britain and Northern Ir...                 0.001488
# ...                                                                     ...
# Tajikistan                                                         0.002094
# Argentina                                                          0.002687
# Türkiye                                                            0.002074
# South Sudan                                                        0.006937
# Sudan                                                              0.005045
#
#                                                     dependency_ratio  ...  \
# country                                                               ...
# Afghanistan                                                      0.0  ...
# Belgium                                                          0.0  ...
# Mauritius                                                        0.0  ...
# Mauritania                                                       0.0  ...
# United Kingdom of Great Britain and Northern Ir...               0.0  ...
# ...                                                              ...  ...
# Tajikistan                                                       0.0  ...
# Argentina                                                        0.0  ...
# Türkiye                                                          0.0  ...
# South Sudan                                                      0.0  ...
# Sudan                                                            0.0  ...
#
#                                                     total_internal_renewable_water_resources  \
# country
# Afghanistan                                                                              0.0
# Belgium                                                                                  0.0
# Mauritius                                                                                0.0
# Mauritania                                                                               0.0
# United Kingdom of Great Britain and Northern Ir...                                       0.0
# ...                                                                                      ...
# Tajikistan                                                                               0.0
# Argentina                                                                                0.0
# Türkiye                                                                                  0.0
# South Sudan                                                                              0.0
# Sudan                                                                                    0.0
#
#                                                     total_internal_renewable_water_resources_per_capita  \
# country
# Afghanistan                                                                                  0.026876
# Belgium                                                                                      0.001678
# Mauritius                                                                                    0.000711
# Mauritania                                                                                   0.019411
# United Kingdom of Great Britain and Northern Ir...                                           0.001488
# ...                                                                                               ...
# Tajikistan                                                                                   0.001354
# Argentina                                                                                    0.003701
# Türkiye                                                                                      0.005517
# South Sudan                                                                                  0.021708
# Sudan                                                                                        0.005041
#
#                                                     total_population  \
# country
# Afghanistan                                                 0.002619
# Belgium                                                     0.001162
# Mauritius                                                   0.000714
# Mauritania                                                  0.003535
# United Kingdom of Great Britain and Northern Ir...          0.001050
# ...                                                              ...
# Tajikistan                                                  0.003977
# Argentina                                                   0.001006
# Türkiye                                                     0.002281
# South Sudan                                                 0.018274
# Sudan                                                       0.006421
#
#                                                     total_population_with_access_to_safe_drinking_water  \
# country
# Afghanistan                                                                                  0.019023
# Belgium                                                                                      0.000000
# Mauritius                                                                                    0.000345
# Mauritania                                                                                   0.003767
# United Kingdom of Great Britain and Northern Ir...                                           0.000000
# ...                                                                                               ...
# Tajikistan                                                                                   0.004815
# Argentina                                                                                    0.004295
# Türkiye                                                                                      0.001250
# South Sudan                                                                                  0.000000
# Sudan                                                                                        0.000000
#
#                                                     total_renewable_groundwater  \
# country
# Afghanistan                                                                 0.0
# Belgium                                                                     0.0
# Mauritius                                                                   0.0
# Mauritania                                                                  0.0
# United Kingdom of Great Britain and Northern Ir...                          0.0
# ...                                                                         ...
# Tajikistan                                                                  0.0
# Argentina                                                                   0.0
# Türkiye                                                                     0.0
# South Sudan                                                                 0.0
# Sudan                                                                       0.0
#
#                                                     total_renewable_water_resources_per_capita  \
# country
# Afghanistan                                                                           0.026876
# Belgium                                                                               0.001678
# Mauritius                                                                             0.000711
# Mauritania                                                                            0.019411
# United Kingdom of Great Britain and Northern Ir...                                    0.001488
# ...                                                                                        ...
# Tajikistan                                                                            0.001350
# Argentina                                                                             0.003701
# Türkiye                                                                               0.005517
# South Sudan                                                                           0.021708
# Sudan                                                                                 0.005045
#
#                                                     total_water_withdrawal  \
# country
# Afghanistan                                                   3.524711e-07
# Belgium                                                       9.219062e-02
# Mauritius                                                     5.456246e-02
# Mauritania                                                    2.539619e-05
# United Kingdom of Great Britain and Northern Ir...            2.614945e-02
# ...                                                                    ...
# Tajikistan                                                    1.502506e-01
# Argentina                                                     3.617521e-04
# Türkiye                                                       7.627695e-02
# South Sudan                                                   0.000000e+00
# Sudan                                                         0.000000e+00
#
#                                                     total_water_withdrawal_per_capita  \
# country
# Afghanistan                                                                  0.027041
# Belgium                                                                      0.104938
# Mauritius                                                                    0.058135
# Mauritania                                                                   0.011609
# United Kingdom of Great Britain and Northern Ir...                           0.027841
# ...                                                                               ...
# Tajikistan                                                                   0.156499
# Argentina                                                                    0.001651
# Türkiye                                                                      0.069148
# South Sudan                                                                  0.021708
# Sudan                                                                        0.005045
#
#                                                     urban_population  \
# country
# Afghanistan                                                 0.003293
# Belgium                                                     0.000533
# Mauritius                                                   0.004297
# Mauritania                                                  0.005414
# United Kingdom of Great Britain and Northern Ir...          0.000102
# ...                                                              ...
# Tajikistan                                                  0.006665
# Argentina                                                   0.000236
# Türkiye                                                     0.001455
# South Sudan                                                 0.013118
# Sudan                                                       0.017395
#
#                                                     water_resources_total_external_renewable
# country
# Afghanistan                                                                              0.0
# Belgium                                                                                  0.0
# Mauritius                                                                                0.0
# Mauritania                                                                               0.0
# United Kingdom of Great Britain and Northern Ir...                                       0.0
# ...                                                                                      ...
# Tajikistan                                                                               0.0
# Argentina                                                                                0.0
# Türkiye                                                                                  0.0
# South Sudan                                                                              0.0
# Sudan                                                                                    0.0
#
# [163 rows x 39 columns]

# %%
df_mape_uni[var_list].loc["Afghanistan"]
# Out:
# %_of_agricultural_gva_produced_by_irrigated_agriculture                  9.604464e-04
# %_of_agricultural_water_managed_area_equipped_for_irrigation             0.000000e+00
# %_of_total_country_area_cultivated                                       1.191064e-02
# agricultural_water_withdrawal                                            0.000000e+00
# agricultural_water_withdrawal_as_%_of_total_renewable_water_resources    0.000000e+00
# agricultural_water_withdrawal_as_%_of_total_water_withdrawal             3.478434e-07
# agriculture_value_added_%_gdp                                            1.029024e-01
# cultivated_area_arable_land_plus_permanent_crops                         1.192542e-02
# dam_capacity_per_capita                                                  2.687638e-02
# dependency_ratio                                                         0.000000e+00
# gdp_per_capita                                                           1.660515e-01
# groundwater_accounted_inflow                                             0.000000e+00
# groundwater_entering_the_country_total                                   0.000000e+00
# industrial_water_withdrawal                                              1.925679e-05
# municipal_water_withdrawal                                               1.925679e-05
# national_rainfall_index                                                  0.000000e+00
# population_density                                                       2.586793e-03
# ratio_between_rainfed_and_irrigated_yields                               0.000000e+00
# rural_population                                                         8.349695e-03
# industrial_water_use_efficiency                                          2.408919e-01
# irrigated_agriculture_water_use_efficiency                               7.307416e-02
# services_water_use_efficiency                                            5.764209e-02
# water_use_efficiency                                                     1.699806e-02
# water_stress                                                             0.000000e+00
# surface_water_entering_the_country_total                                 0.000000e+00
# surface_water_leaving_the_country_to_other_countries_total               0.000000e+00
# total_agricultural_water_managed_area                                    1.892691e-08
# total_area_of_the_country_excl_coastal_water                             0.000000e+00
# total_dam_capacity                                                       0.000000e+00
# total_internal_renewable_water_resources                                 0.000000e+00
# total_internal_renewable_water_resources_per_capita                      2.687621e-02
# total_population                                                         2.619119e-03
# total_population_with_access_to_safe_drinking_water                      1.902271e-02
# total_renewable_groundwater                                              0.000000e+00
# total_renewable_water_resources_per_capita                               2.687621e-02
# total_water_withdrawal                                                   3.524711e-07
# total_water_withdrawal_per_capita                                        2.704132e-02
# urban_population                                                         3.293312e-03
# water_resources_total_external_renewable                                 0.000000e+00
# Name: Afghanistan, dtype: float64

# %%
from amwag.app_utilities.app_utilities import *

# %%
reverse_var_name_dict = create_reverse_var_name_dict(df_ts.reset_index())
nice_var_name_list = [reverse_var_name_dict[var] for var in var_list]
nice_var_name_list
# Out:
# ['percentage of agricultural gva produced by irrigated agriculture',
#  'percentage of agricultural water managed area equipped for irrigation',
#  'percentage of total country area cultivated',
#  'agricultural water withdrawal',
#  'agricultural water withdrawal as percentage of total renewable water resources',
#  'agricultural water withdrawal as percentage of total water withdrawal',
#  'agriculture value added percentage gdp',
#  'cultivated area arable land plus permanent crops',
#  'dam capacity per capita',
#  'dependency ratio',
#  'gdp per capita',
#  'groundwater accounted inflow',
#  'groundwater entering the country total',
#  'industrial water withdrawal',
#  'municipal water withdrawal',
#  'national rainfall index',
#  'population density',
#  'ratio between rainfed and irrigated yields',
#  'rural population',
#  'industrial water use efficiency',
#  'irrigated agriculture water use efficiency',
#  'services water use efficiency',
#  'water use efficiency',
#  'water stress',
#  'surface water entering the country total',
#  'surface water leaving the country to other countries total',
#  'total agricultural water managed area',
#  'total area of the country excl coastal water',
#  'total dam capacity',
#  'total internal renewable water resources',
#  'total internal renewable water resources per capita',
#  'total population',
#  'total population with access to safe drinking water',
#  'total renewable groundwater',
#  'total renewable water resources per capita',
#  'total water withdrawal',
#  'total water withdrawal per capita',
#  'urban population',
#  'water resources total external renewable']

# %%
len(nice_var_name_list)
# Out:
# 39

# %%
df_mape_multi.isna().sum().sum()
# Out:
# 0

# %%
fig, axs = plt.subplots(1,2, figsize=(12,4), sharey=True, sharex=True)

for i, c in enumerate(fc.country.unique()):
    print(i, c)
    if i==0:
        axs[0].plot(nice_var_name_list, df_mape_uni[var_list].loc[c], "o", alpha=0.2, color="C0", label="univariate")
        axs[1].plot(nice_var_name_list, df_mape_multi[var_list].loc[c], "o", alpha=0.2, color="C1", label="multivariate")
    else:
        axs[0].plot(nice_var_name_list, df_mape_uni[var_list].loc[c], "o", alpha=0.2, color="C0")
        axs[1].plot(nice_var_name_list, df_mape_multi[var_list].loc[c], "o", alpha=0.2, color="C1")
axs[0].set_yscale("log")
axs[0].set_ylabel("MAPE")
axs[0].set_title("Holt Winters'")
axs[1].set_title("VAR")
axs[0].legend(loc="lower right")
axs[1].legend(loc="lower right")
for ax in axs:
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, fontsize=8)
fig.tight_layout()
# Out:
# 0 Afghanistan
# 1 Belgium
# 2 Mauritius
# 3 Mauritania
# 4 United Kingdom of Great Britain and Northern Ireland
# 5 Malta
# 6 Mali
# 7 Belize
# 8 Malaysia
# 9 Malawi
# 10 Madagascar
# 11 Luxembourg
# 12 Benin
# 13 Lithuania
# 14 Mexico
# 15 Libya
# 16 Lesotho
# 17 United Republic of Tanzania
# 18 Bhutan
# 19 Lebanon
# 20 Latvia
# 21 Lao People's Democratic Republic
# 22 Bolivia (Plurinational State of)
# 23 Kyrgyzstan
# 24 Kuwait
# 25 Kenya
# 26 Kazakhstan
# 27 Botswana
# 28 Jordan
# 29 Liberia
# 30 Japan
# 31 Mongolia
# 32 Mozambique
# 33 Austria
# 34 Portugal
# 35 Poland
# 36 Philippines
# 37 Peru
# 38 Azerbaijan
# 39 Paraguay
# 40 Panama
# 41 Ukraine
# 42 Palestine
# 43 Zimbabwe
# 44 Bahrain
# 45 Pakistan
# 46 Morocco
# 47 Oman
# 48 North Macedonia
# 49 Bangladesh
# 50 Nigeria
# 51 Niger
# 52 Nicaragua
# 53 New Zealand
# 54 Netherlands (Kingdom of the)
# 55 Barbados
# 56 United Arab Emirates
# 57 Nepal
# 58 Namibia
# 59 Myanmar
# 60 Belarus
# 61 Norway
# 62 Puerto Rico
# 63 United States of America
# 64 Zambia
# 65 Cameroon
# 66 Ethiopia
# 67 Eswatini
# 68 Estonia
# 69 Eritrea
# 70 Venezuela (Bolivarian Republic of)
# 71 Canada
# 72 El Salvador
# 73 Egypt
# 74 Ecuador
# 75 Central African Republic
# 76 Dominican Republic
# 77 Denmark
# 78 Fiji
# 79 Democratic Republic of the Congo
# 80 Yemen
# 81 Chad
# 82 Côte d'Ivoire
# 83 Czechia
# 84 Viet Nam
# 85 Cyprus
# 86 Chile
# 87 Cuba
# 88 Croatia
# 89 Costa Rica
# 90 Congo
# 91 China
# 92 Comoros
# 93 Democratic People's Republic of Korea
# 94 Jamaica
# 95 Finland
# 96 Gabon
# 97 Brazil
# 98 Italy
# 99 Israel
# 100 Ireland
# 101 Iraq
# 102 Bulgaria
# 103 Iran (Islamic Republic of)
# 104 Indonesia
# 105 India
# 106 Iceland
# 107 Hungary
# 108 Burkina Faso
# 109 Uruguay
# 110 France
# 111 Honduras
# 112 Guyana
# 113 Burundi
# 114 Guinea-Bissau
# 115 Guinea
# 116 Guatemala
# 117 Greece
# 118 Cabo Verde
# 119 Ghana
# 120 Germany
# 121 Uzbekistan
# 122 Georgia
# 123 Gambia
# 124 Cambodia
# 125 Haiti
# 126 Qatar
# 127 Colombia
# 128 Switzerland
# 129 Romania
# 130 South Africa
# 131 Sweden
# 132 Uganda
# 133 Australia
# 134 Syrian Arab Republic
# 135 Tunisia
# 136 Slovakia
# 137 Armenia
# 138 Somalia
# 139 Turkmenistan
# 140 Albania
# 141 Sierra Leone
# 142 Spain
# 143 Suriname
# 144 Rwanda
# 145 Thailand
# 146 Trinidad and Tobago
# 147 Sri Lanka
# 148 Senegal
# 149 Republic of Korea
# 150 Slovenia
# 151 Algeria
# 152 Russian Federation
# 153 Togo
# 154 Timor-Leste
# 155 Saudi Arabia
# 156 Angola
# 157 Republic of Moldova
# 158 Tajikistan
# 159 Argentina
# 160 Türkiye
# 161 South Sudan
# 162 Sudan
